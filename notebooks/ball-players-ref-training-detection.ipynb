# %%
import os 
import shutil
from ultralytics import YOLO
import torch

# %% [markdown]
# ## Prepare Paths

# %%
NOTEBOOKS_PATH = os.getcwd()
print(NOTEBOOKS_PATH)
# Out:
# /home/gomaa/Ai/projects/Football-Match-Analysis/notebooks

# %%
PROJECT_PATH = os.path.dirname(NOTEBOOKS_PATH)
print(PROJECT_PATH)
# Out:
# /home/gomaa/Ai/projects/Football-Match-Analysis

# %%
DATA_PATH = os.path.join(PROJECT_PATH, 'data')
MODELS_PATH = os.path.join(PROJECT_PATH, 'models')
print(f"Data Path: {DATA_PATH}")
print(f"Models Path: {MODELS_PATH}")
# Out:
# Data Path: /home/gomaa/Ai/projects/Football-Match-Analysis/data
# Models Path: /home/gomaa/Ai/projects/Football-Match-Analysis/models

# %%
dataset_dir_name = 'football-players-detection-dataset'
DATASET_PATH = os.path.join(DATA_PATH, dataset_dir_name)
print(f"Dataset Path: {DATASET_PATH}")
# Out:
# Dataset Path: /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset

# %%
DATA_YAML_PATH = os.path.join(DATASET_PATH, 'data.yaml')
print(DATA_YAML_PATH)
# Out:
# /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/data.yaml

# %%
TRAIN_IMGS_PATH = os.path.join(DATASET_PATH, 'train/images')
TRAIN_LBLS_PATH = os.path.join(DATASET_PATH, 'train/labels')

VALID_IMGS_PATH = os.path.join(DATASET_PATH, 'valid/images')
VALID_LBLS_PATH = os.path.join(DATASET_PATH, 'valid/labels')

TEST_IMGS_PATH = os.path.join(DATASET_PATH, 'test/images')
TEST_LBLS_PATH = os.path.join(DATASET_PATH, 'test/labels')

print(f"Train images path: {TRAIN_IMGS_PATH}")
print(f"Train labels path: {TRAIN_LBLS_PATH}")
print(f"Valid images path: {VALID_IMGS_PATH}")
print(f"Valid labels path: {VALID_LBLS_PATH}")
print(f"Test images path: {TEST_IMGS_PATH}")
print(f"Test labels path: {TEST_LBLS_PATH}")
# Out:
# Train images path: /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/train/images
# Train labels path: /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/train/labels
# Valid images path: /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/valid/images
# Valid labels path: /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/valid/labels
# Test images path: /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images
# Test labels path: /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/labels

# %% [markdown]
# # Train YOLOv8 Model

# %%
print("CUDA available:", torch.cuda.is_available())
print("GPU count:", torch.cuda.device_count())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# CUDA available: True
# GPU count: 1
# Device: NVIDIA GeForce RTX 2050

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(DEVICE)
# Out:
# cuda

# %%
model = YOLO("yolov8m.pt")

# %%
EPOCHS = 50
IMG_SIZE = 1024
BATCH_SIZE = 4

# %%
model.train(
    data=DATA_YAML_PATH,
    epochs=EPOCHS,
    imgsz = IMG_SIZE,
    batch = BATCH_SIZE,
    project = MODELS_PATH,
    plots=True
)

# %% [markdown]
# ### Test Model

# %%
TRAINED_MODEL_PATH = os.path.join(MODELS_PATH, 'train5/weights/best.pt')
print(f"Trained Model path: {TRAINED_MODEL_PATH}")
# Out:
# Trained Model path: /home/gomaa/Ai/projects/Football-Match-Analysis/models/train5/weights/best.pt

# %%
trained_model = YOLO(TRAINED_MODEL_PATH)

# %%
results = trained_model.val(data=DATA_YAML_PATH,split='val',imgsz=1024)

# %%
results = trained_model.val(data=DATA_YAML_PATH,split='test',imgsz=1024)

# %%
RESULTS_PATH = os.path.join(PROJECT_PATH,'runs')
print(f"Results path: {RESULTS_PATH}")
# Out:
# Results path: /home/gomaa/Ai/projects/Football-Match-Analysis/runs

# %%
trained_model.predict(source=TEST_IMGS_PATH,
              conf=0.4,
              save=True,
              classes = [0,1,2,3],
              project = RESULTS_PATH)
# Out:
# image 1/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/08fd33_3_6_png.rf.261781c58b95436fb40e6afc0495bc57.jpg: 1024x1024 1 ball, 20 players, 2 referees, 156.4ms
# image 2/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/08fd33_9_3_png.rf.20ff5bcc914d7f607cf9425c73da679c.jpg: 1024x1024 20 players, 1 referee, 151.3ms
# image 3/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/40cd38_7_6_png.rf.3e49856b19208cd7b616cd826a793f08.jpg: 1024x1024 21 players, 1 referee, 151.7ms
# image 4/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/42ba34_1_5_png.rf.e530a34d1588130dae6f6cba815688ce.jpg: 1024x1024 1 ball, 1 goalkeeper, 20 players, 2 referees, 151.9ms
# image 5/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/42ba34_5_5_png.rf.4153d27549bb9aad06d11a54c1ea3dc3.jpg: 1024x1024 1 goalkeeper, 19 players, 1 referee, 151.2ms
# image 6/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_4_png.rf.746881815061da6082d636894dbb523f.jpg: 1024x1024 1 goalkeeper, 20 players, 3 referees, 152.1ms
# image 7/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_6_png.rf.83c3cdc332120b9da3c017083daaa489.jpg: 1024x1024 20 players, 3 referees, 151.6ms
# image 8/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_8_png.rf.3d4f596483faaa1d25084d5317ea71fd.jpg: 1024x1024 1 ball, 1 goalkeeper, 20 players, 2 referees, 151.9ms
# image 9/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_3_6_png.rf.00d0b5f62d7a263ec314a7f6feca6936.jpg: 1024x1024 1 goalkeeper, 20 players, 2 referees, 151.1ms
# image 10/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_3_9_png.rf.1185713c3c0f110b6daf1176d5743755.jpg: 1024x1024 1 ball, 19 players, 2 referees, 151.3ms
# image 11/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_5_1_png.rf.79a7fb518f57a14552c4a2e27c7d287e.jpg: 1024x1024 1 ball, 1 goalkeeper, 20 players, 3 referees, 151.8ms
# image 12/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_9_3_png.rf.77259c789c1e3777d5dbc1f55e6cb22f.jpg: 1024x1024 1 goalkeeper, 20 players, 3 referees, 151.2ms
# image 13/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_9_4_png.rf.c45fd1178606ed8fe6c0acaf12f59f8b.jpg: 1024x1024 1 ball, 1 goalkeeper, 22 players, 3 referees, 151.9ms
# image 14/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/538438_3_6_png.rf.3394ec92531a1a42f7a73ee1050ae63a.jpg: 1024x1024 1 goalkeeper, 20 players, 3 referees, 151.9ms
# image 15/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/538438_5_2_png.rf.a01dbe54ed6d85f492f25265f5d2362c.jpg: 1024x1024 1 goalkeeper, 20 players, 1 referee, 151.2ms
# image 16/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/573e61_1_9_png.rf.8da2275498160aa3f377ff7045d294b8.jpg: 1024x1024 19 players, 2 referees, 151.2ms
# image 17/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/573e61_9_6_png.rf.1d9472b7b7c4a74a93a926c6047cd2af.jpg: 1024x1024 1 goalkeeper, 20 players, 3 referees, 152.1ms
# image 18/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_1_10_png.rf.cabe7f0ac5c75671f5cd8ebf2dea597a.jpg: 1024x1024 1 goalkeeper, 20 players, 2 referees, 152.2ms
# image 19/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_7_4_png.rf.eb099bcea99cf692889ab77d9f679b5a.jpg: 1024x1024 1 goalkeeper, 20 players, 3 referees, 152.0ms
# image 20/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_9_9_png.rf.66884f75e67df321142d2600f1c7a3f1.jpg: 1024x1024 1 goalkeeper, 20 players, 1 referee, 151.4ms
# image 21/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_3_10_png.rf.00e76ea90f2abc32e09334c3194c7c49.jpg: 1024x1024 1 ball, 21 players, 2 referees, 151.6ms
# image 22/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_3_3_png.rf.f62ed4e82697a2930b4d9bdd6ece0f9b.jpg: 1024x1024 1 goalkeeper, 20 players, 2 referees, 151.9ms
# image 23/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_7_8_png.rf.30060820d1e9b058ac2c519039d057aa.jpg: 1024x1024 1 ball, 20 players, 2 referees, 152.6ms
# image 24/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/a9f16c_2_10_png.rf.7a5ffdc0b8955577fe953b92a257078b.jpg: 1024x1024 1 ball, 1 goalkeeper, 18 players, 3 referees, 152.3ms
# image 25/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/a9f16c_2_9_png.rf.3d70706303f110aedc833f5c8912b233.jpg: 1024x1024 1 goalkeeper, 20 players, 3 referees, 151.1ms
# Speed: 4.6ms preprocess, 151.9ms inference, 4.9ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[255, 253, 249],
#          [255, 254, 250],
#          [254, 255, 251],
#          ...,
#          [106,  94,  76],
#          [122, 110,  92],
#          [113, 101,  83]],
#
#         [[255, 254, 250],
#          [255, 254, 250],
#          [254, 255, 251],
#          ...,
#          [106,  94,  76],
#          [128, 116,  98],
#          [116, 104,  86]],
#
#         [[255, 254, 250],
#          [253, 254, 250],
#          [252, 255, 251],
#          ...,
#          [140, 130, 113],
#          [136, 126, 109],
#          [ 94,  84,  67]],
#
#         ...,
#
#         [[145, 147, 117],
#          [139, 141, 112],
#          [147, 144, 116],
#          ...,
#          [ 55,  53,  45],
#          [105, 103,  95],
#          [102, 100,  92]],
#
#         [[146, 148, 119],
#          [140, 142, 113],
#          [146, 142, 117],
#          ...,
#          [ 60,  58,  50],
#          [110, 108, 100],
#          [107, 105,  97]],
#
#         [[145, 147, 118],
#          [138, 140, 111],
#          [144, 140, 116],
#          ...,
#          [ 74,  72,  64],
#          [108, 106,  98],
#          [ 91,  89,  81]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/08fd33_3_6_png.rf.261781c58b95436fb40e6afc0495bc57.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 19.359932999577723, 'inference': 156.3605049996113, 'postprocess': 4.556904001219664},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[125, 111,  99],
#          [124, 110,  98],
#          [122, 108,  96],
#          ...,
#          [ 74,  57,  54],
#          [ 71,  52,  47],
#          [ 85,  66,  61]],
#
#         [[127, 113, 101],
#          [129, 115, 103],
#          [127, 113, 101],
#          ...,
#          [ 71,  54,  51],
#          [ 62,  43,  38],
#          [ 81,  62,  57]],
#
#         [[114, 100,  88],
#          [117, 103,  91],
#          [115, 103,  91],
#          ...,
#          [ 78,  62,  56],
#          [ 72,  56,  50],
#          [104,  88,  82]],
#
#         ...,
#
#         [[ 83, 107,  89],
#          [ 81, 107,  89],
#          [ 82, 105,  90],
#          ...,
#          [ 72,  64,  64],
#          [ 69,  61,  62],
#          [ 65,  57,  58]],
#
#         [[ 78, 104,  88],
#          [ 76, 103,  87],
#          [ 76, 102,  86],
#          ...,
#          [ 65,  59,  60],
#          [ 56,  49,  52],
#          [ 58,  51,  54]],
#
#         [[ 77, 104,  88],
#          [ 77, 104,  88],
#          [ 76, 103,  87],
#          ...,
#          [ 63,  57,  58],
#          [ 52,  45,  50],
#          [ 65,  58,  63]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/08fd33_9_3_png.rf.20ff5bcc914d7f607cf9425c73da679c.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.0739060004852945, 'inference': 151.33810600127617, 'postprocess': 4.323997000028612},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[107, 115,  98],
#          [103, 111,  94],
#          [106, 115,  95],
#          ...,
#          [255, 250, 177],
#          [255, 248, 178],
#          [255, 248, 178]],
#
#         [[112, 119, 106],
#          [120, 127, 114],
#          [107, 114,  99],
#          ...,
#          [215, 207, 137],
#          [213, 202, 134],
#          [209, 200, 132]],
#
#         [[ 97, 102, 100],
#          [101, 107, 102],
#          [ 98, 105,  98],
#          ...,
#          [161, 152,  88],
#          [160, 150,  86],
#          [158, 149,  85]],
#
#         ...,
#
#         [[ 44,  59,  68],
#          [ 27,  42,  51],
#          [ 49,  61,  71],
#          ...,
#          [ 51,  49,  48],
#          [ 51,  50,  52],
#          [ 53,  52,  54]],
#
#         [[ 43,  57,  69],
#          [ 33,  47,  59],
#          [ 44,  58,  70],
#          ...,
#          [ 53,  46,  49],
#          [ 63,  56,  63],
#          [ 60,  55,  64]],
#
#         [[ 37,  51,  63],
#          [ 34,  48,  60],
#          [ 40,  53,  67],
#          ...,
#          [ 53,  46,  51],
#          [ 63,  53,  65],
#          [ 50,  41,  54]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/40cd38_7_6_png.rf.3e49856b19208cd7b616cd826a793f08.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.8290150005195756, 'inference': 151.66288200089184, 'postprocess': 4.790669001522474},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[109, 114,  83],
#          [128, 133, 101],
#          [153, 158, 126],
#          ...,
#          [149, 167, 150],
#          [140, 159, 140],
#          [131, 150, 131]],
#
#         [[118, 121,  95],
#          [112, 116,  87],
#          [125, 130,  99],
#          ...,
#          [153, 171, 154],
#          [147, 165, 148],
#          [141, 160, 141]],
#
#         [[131, 133, 113],
#          [122, 125, 103],
#          [132, 136, 111],
#          ...,
#          [150, 165, 151],
#          [145, 162, 148],
#          [141, 159, 142]],
#
#         ...,
#
#         [[ 62,  67,  66],
#          [ 62,  67,  66],
#          [ 42,  45,  43],
#          ...,
#          [ 65,  66,  64],
#          [ 68,  68,  62],
#          [ 64,  65,  55]],
#
#         [[ 59,  64,  62],
#          [ 63,  68,  66],
#          [ 42,  45,  43],
#          ...,
#          [ 55,  56,  54],
#          [ 59,  59,  53],
#          [ 62,  63,  54]],
#
#         [[ 54,  59,  57],
#          [ 63,  68,  66],
#          [ 44,  47,  45],
#          ...,
#          [ 52,  52,  52],
#          [ 57,  57,  51],
#          [ 66,  67,  58]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/42ba34_1_5_png.rf.e530a34d1588130dae6f6cba815688ce.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.05403600052523, 'inference': 151.90997699937725, 'postprocess': 4.81559699983336},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 79,  53,  53],
#          [ 68,  43,  41],
#          [128, 106, 101],
#          ...,
#          [155, 141, 143],
#          [156, 142, 144],
#          [157, 143, 145]],
#
#         [[ 72,  46,  46],
#          [ 90,  67,  65],
#          [148, 126, 120],
#          ...,
#          [ 97,  84,  86],
#          [ 99,  86,  88],
#          [100,  87,  89]],
#
#         [[101,  78,  76],
#          [ 95,  75,  70],
#          [152, 133, 125],
#          ...,
#          [ 49,  38,  40],
#          [ 51,  40,  42],
#          [ 52,  41,  43]],
#
#         ...,
#
#         [[ 44,  97,  53],
#          [ 44,  97,  53],
#          [ 44,  97,  53],
#          ...,
#          [ 87,  93,  70],
#          [ 87,  93,  70],
#          [ 88,  94,  71]],
#
#         [[ 44,  97,  53],
#          [ 44,  97,  53],
#          [ 44,  97,  53],
#          ...,
#          [ 86,  91,  70],
#          [ 86,  91,  70],
#          [ 87,  92,  71]],
#
#         [[ 44,  97,  53],
#          [ 44,  97,  53],
#          [ 44,  97,  53],
#          ...,
#          [ 85,  90,  69],
#          [ 86,  91,  70],
#          [ 87,  92,  71]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/42ba34_5_5_png.rf.4153d27549bb9aad06d11a54c1ea3dc3.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.070191998835071, 'inference': 151.20131599906017, 'postprocess': 4.301345999920159},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 30,  35,  34],
#          [ 31,  36,  35],
#          [ 32,  37,  36],
#          ...,
#          [ 53,  66,  68],
#          [ 39,  54,  56],
#          [ 22,  37,  39]],
#
#         [[ 30,  35,  34],
#          [ 30,  35,  34],
#          [ 30,  35,  34],
#          ...,
#          [ 41,  56,  58],
#          [ 33,  48,  50],
#          [ 21,  36,  38]],
#
#         [[ 29,  34,  33],
#          [ 29,  34,  33],
#          [ 28,  33,  32],
#          ...,
#          [ 35,  53,  54],
#          [ 32,  50,  51],
#          [ 27,  45,  46]],
#
#         ...,
#
#         [[ 58, 122, 127],
#          [ 84, 147, 151],
#          [ 85, 141, 146],
#          ...,
#          [170, 155, 159],
#          [182, 165, 169],
#          [186, 171, 175]],
#
#         [[ 37, 107, 114],
#          [ 66, 134, 139],
#          [ 69, 132, 136],
#          ...,
#          [165, 147, 154],
#          [166, 145, 153],
#          [163, 145, 152]],
#
#         [[ 29, 101, 108],
#          [ 52, 123, 127],
#          [ 52, 116, 121],
#          ...,
#          [183, 162, 170],
#          [177, 156, 164],
#          [169, 148, 156]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_4_png.rf.746881815061da6082d636894dbb523f.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.407929000080912, 'inference': 152.05157700074778, 'postprocess': 4.793576001247857},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 30,  43,  45],
#          [ 40,  53,  55],
#          [ 31,  44,  46],
#          ...,
#          [ 40,  45,  43],
#          [ 39,  46,  41],
#          [ 39,  46,  41]],
#
#         [[ 21,  34,  36],
#          [ 29,  42,  44],
#          [ 22,  35,  37],
#          ...,
#          [ 39,  44,  42],
#          [ 38,  45,  40],
#          [ 38,  45,  40]],
#
#         [[ 21,  34,  36],
#          [ 27,  40,  42],
#          [ 23,  35,  37],
#          ...,
#          [ 41,  46,  44],
#          [ 39,  46,  41],
#          [ 39,  46,  41]],
#
#         ...,
#
#         [[ 65, 114, 128],
#          [ 75, 122, 136],
#          [ 62, 105, 120],
#          ...,
#          [ 27,  38,  42],
#          [ 35,  47,  49],
#          [ 43,  53,  53]],
#
#         [[ 28,  66,  84],
#          [ 23,  59,  77],
#          [ 22,  52,  71],
#          ...,
#          [ 37,  46,  49],
#          [ 43,  51,  51],
#          [ 34,  42,  41]],
#
#         [[ 25,  58,  77],
#          [ 30,  62,  81],
#          [ 33,  57,  77],
#          ...,
#          [ 54,  64,  64],
#          [ 64,  69,  70],
#          [ 46,  52,  51]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_6_png.rf.83c3cdc332120b9da3c017083daaa489.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.165243999523227, 'inference': 151.58035599961295, 'postprocess': 4.7291280006902525},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 42,  65,  81],
#          [ 51,  74,  90],
#          [ 55,  76,  91],
#          ...,
#          [ 18,  22,  23],
#          [ 18,  23,  26],
#          [ 19,  24,  27]],
#
#         [[ 62,  82,  99],
#          [ 50,  71,  86],
#          [ 46,  67,  82],
#          ...,
#          [ 20,  24,  25],
#          [ 20,  25,  28],
#          [ 21,  26,  29]],
#
#         [[ 59,  78,  93],
#          [ 31,  50,  63],
#          [ 28,  47,  60],
#          ...,
#          [ 23,  27,  28],
#          [ 21,  26,  29],
#          [ 21,  26,  29]],
#
#         ...,
#
#         [[ 80, 125, 108],
#          [ 81, 129, 111],
#          [ 83, 130, 114],
#          ...,
#          [ 25,  41,  53],
#          [ 25,  42,  55],
#          [ 10,  29,  44]],
#
#         [[ 66, 118, 101],
#          [ 66, 118, 101],
#          [ 63, 114, 100],
#          ...,
#          [ 26,  42,  54],
#          [ 26,  43,  56],
#          [  6,  25,  40]],
#
#         [[ 70, 124, 107],
#          [ 66, 120, 103],
#          [ 60, 115, 100],
#          ...,
#          [ 20,  36,  48],
#          [ 12,  29,  42],
#          [ 17,  36,  51]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_8_png.rf.3d4f596483faaa1d25084d5317ea71fd.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.9878259995020926, 'inference': 151.87576199969044, 'postprocess': 5.083202999230707},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 25,  29,  30],
#          [  9,  13,  14],
#          [ 30,  34,  35],
#          ...,
#          [ 22,  21,  23],
#          [ 24,  21,  23],
#          [ 26,  23,  25]],
#
#         [[ 28,  32,  33],
#          [ 15,  19,  20],
#          [ 36,  40,  41],
#          ...,
#          [ 17,  16,  18],
#          [ 23,  22,  24],
#          [ 31,  30,  32]],
#
#         [[ 28,  32,  33],
#          [ 18,  22,  23],
#          [ 37,  41,  42],
#          ...,
#          [ 16,  18,  19],
#          [ 26,  28,  29],
#          [ 40,  42,  43]],
#
#         ...,
#
#         [[  9,   9,   9],
#          [  8,   8,   8],
#          [  7,   7,   7],
#          ...,
#          [137, 218, 221],
#          [110, 187, 189],
#          [ 49, 127, 126]],
#
#         [[  9,   9,   9],
#          [  8,   8,   8],
#          [  7,   7,   7],
#          ...,
#          [136, 221, 223],
#          [122, 208, 208],
#          [ 90, 173, 174]],
#
#         [[  9,   9,   9],
#          [  8,   8,   8],
#          [  7,   7,   7],
#          ...,
#          [129, 219, 220],
#          [133, 220, 222],
#          [138, 226, 226]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_3_6_png.rf.00d0b5f62d7a263ec314a7f6feca6936.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.180277001069044, 'inference': 151.09412200035877, 'postprocess': 5.078026000774116},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 25,  49,  39],
#          [ 31,  52,  43],
#          [ 35,  53,  46],
#          ...,
#          [ 18,  22,  23],
#          [ 41,  45,  46],
#          [ 49,  53,  54]],
#
#         [[ 25,  49,  39],
#          [ 28,  49,  40],
#          [ 32,  50,  43],
#          ...,
#          [ 20,  24,  25],
#          [ 33,  37,  38],
#          [ 45,  49,  50]],
#
#         [[ 26,  49,  41],
#          [ 25,  46,  38],
#          [ 29,  47,  40],
#          ...,
#          [ 31,  36,  37],
#          [ 30,  35,  36],
#          [ 46,  51,  52]],
#
#         ...,
#
#         [[ 24,  33,  36],
#          [ 21,  30,  33],
#          [ 17,  29,  31],
#          ...,
#          [ 16, 109, 100],
#          [ 19, 109, 103],
#          [ 18, 111, 102]],
#
#         [[ 20,  28,  28],
#          [ 18,  28,  28],
#          [ 20,  30,  30],
#          ...,
#          [ 43, 143, 131],
#          [ 34, 131, 121],
#          [ 25, 125, 113]],
#
#         [[ 20,  28,  28],
#          [ 22,  30,  30],
#          [ 24,  34,  34],
#          ...,
#          [ 93, 195, 183],
#          [ 73, 175, 163],
#          [ 59, 161, 149]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_3_9_png.rf.1185713c3c0f110b6daf1176d5743755.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.8722059998690384, 'inference': 151.32732699930784, 'postprocess': 4.809531999853789},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[12, 20, 19],
#          [20, 28, 27],
#          [25, 33, 32],
#          ...,
#          [74, 84, 72],
#          [66, 76, 63],
#          [58, 68, 55]],
#
#         [[24, 32, 31],
#          [28, 36, 35],
#          [29, 37, 36],
#          ...,
#          [73, 83, 70],
#          [42, 52, 39],
#          [29, 39, 26]],
#
#         [[33, 41, 40],
#          [34, 42, 41],
#          [29, 37, 36],
#          ...,
#          [47, 56, 43],
#          [25, 34, 21],
#          [28, 38, 22]],
#
#         ...,
#
#         [[34, 53, 60],
#          [35, 55, 60],
#          [40, 58, 65],
#          ...,
#          [48, 61, 75],
#          [44, 58, 76],
#          [46, 60, 78]],
#
#         [[42, 64, 69],
#          [44, 65, 67],
#          [45, 64, 69],
#          ...,
#          [45, 58, 72],
#          [36, 50, 68],
#          [40, 55, 74]],
#
#         [[35, 58, 60],
#          [27, 50, 52],
#          [23, 42, 45],
#          ...,
#          [49, 62, 78],
#          [36, 50, 68],
#          [43, 58, 77]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_5_1_png.rf.79a7fb518f57a14552c4a2e27c7d287e.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.724500000316766, 'inference': 151.77871499872708, 'postprocess': 5.328999000994372},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[15, 20, 18],
#          [15, 20, 18],
#          [14, 19, 17],
#          ...,
#          [22, 27, 26],
#          [25, 29, 30],
#          [28, 32, 33]],
#
#         [[15, 20, 18],
#          [15, 20, 18],
#          [14, 19, 17],
#          ...,
#          [22, 26, 27],
#          [24, 28, 29],
#          [26, 30, 31]],
#
#         [[15, 20, 18],
#          [15, 20, 18],
#          [14, 19, 17],
#          ...,
#          [22, 25, 29],
#          [22, 25, 29],
#          [24, 27, 31]],
#
#         ...,
#
#         [[17, 28, 26],
#          [19, 30, 28],
#          [22, 30, 29],
#          ...,
#          [28, 44, 51],
#          [27, 45, 52],
#          [27, 45, 52]],
#
#         [[17, 28, 26],
#          [18, 29, 27],
#          [23, 31, 30],
#          ...,
#          [25, 41, 48],
#          [23, 41, 48],
#          [24, 42, 49]],
#
#         [[16, 27, 25],
#          [18, 29, 27],
#          [23, 31, 30],
#          ...,
#          [23, 39, 46],
#          [20, 38, 45],
#          [21, 39, 46]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_9_3_png.rf.77259c789c1e3777d5dbc1f55e6cb22f.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.8487559995701304, 'inference': 151.21944599923154, 'postprocess': 5.3867560000071535},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[21, 22, 20],
#          [19, 20, 18],
#          [17, 18, 16],
#          ...,
#          [25, 33, 22],
#          [26, 34, 23],
#          [27, 35, 24]],
#
#         [[21, 22, 20],
#          [19, 20, 18],
#          [17, 18, 16],
#          ...,
#          [25, 33, 23],
#          [26, 34, 24],
#          [27, 35, 25]],
#
#         [[21, 22, 20],
#          [19, 20, 18],
#          [17, 18, 16],
#          ...,
#          [24, 32, 25],
#          [25, 33, 26],
#          [25, 33, 26]],
#
#         ...,
#
#         [[21, 23, 11],
#          [25, 27, 15],
#          [30, 32, 20],
#          ...,
#          [ 0, 16,  5],
#          [ 4, 19, 11],
#          [ 8, 21, 13]],
#
#         [[21, 23, 11],
#          [26, 28, 16],
#          [31, 33, 21],
#          ...,
#          [ 5, 28, 14],
#          [ 7, 27, 15],
#          [ 7, 27, 15]],
#
#         [[16, 18,  6],
#          [21, 23, 11],
#          [26, 28, 16],
#          ...,
#          [42, 69, 53],
#          [21, 43, 31],
#          [ 6, 28, 16]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_9_4_png.rf.c45fd1178606ed8fe6c0acaf12f59f8b.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.938143001505523, 'inference': 151.91990099992836, 'postprocess': 5.676321001374163},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 47,  47,  47],
#          [ 48,  48,  48],
#          [ 50,  50,  50],
#          ...,
#          [ 46,  47,  45],
#          [ 45,  46,  44],
#          [ 45,  46,  44]],
#
#         [[ 46,  46,  46],
#          [ 46,  46,  46],
#          [ 47,  47,  47],
#          ...,
#          [ 46,  47,  45],
#          [ 45,  46,  44],
#          [ 45,  46,  44]],
#
#         [[ 46,  46,  46],
#          [ 47,  47,  47],
#          [ 47,  47,  47],
#          ...,
#          [ 45,  46,  44],
#          [ 45,  46,  44],
#          [ 45,  46,  44]],
#
#         ...,
#
#         [[ 42,  57,  59],
#          [ 42,  57,  59],
#          [ 43,  58,  60],
#          ...,
#          [ 93, 114, 115],
#          [ 93, 114, 115],
#          [ 93, 114, 115]],
#
#         [[ 46,  61,  63],
#          [ 46,  61,  63],
#          [ 46,  61,  63],
#          ...,
#          [106, 130, 130],
#          [106, 130, 130],
#          [106, 130, 130]],
#
#         [[ 45,  60,  62],
#          [ 45,  60,  62],
#          [ 44,  59,  61],
#          ...,
#          [130, 154, 154],
#          [129, 153, 153],
#          [129, 153, 153]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/538438_3_6_png.rf.3394ec92531a1a42f7a73ee1050ae63a.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.8976220002950868, 'inference': 151.92528999978094, 'postprocess': 5.349146000298788},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[102, 114, 118],
#          [100, 112, 116],
#          [ 97, 109, 113],
#          ...,
#          [ 18,  23,  22],
#          [ 21,  26,  25],
#          [ 26,  31,  30]],
#
#         [[102, 114, 118],
#          [100, 112, 116],
#          [ 98, 110, 114],
#          ...,
#          [ 17,  22,  21],
#          [ 19,  24,  23],
#          [ 24,  29,  28]],
#
#         [[102, 114, 118],
#          [100, 112, 116],
#          [ 99, 111, 115],
#          ...,
#          [ 16,  21,  20],
#          [ 17,  22,  21],
#          [ 21,  26,  25]],
#
#         ...,
#
#         [[ 37,  83,  70],
#          [ 37,  83,  70],
#          [ 38,  84,  71],
#          ...,
#          [124, 147, 155],
#          [124, 147, 155],
#          [124, 147, 155]],
#
#         [[ 37,  83,  70],
#          [ 37,  83,  70],
#          [ 37,  83,  70],
#          ...,
#          [124, 147, 155],
#          [124, 147, 155],
#          [124, 147, 155]],
#
#         [[ 35,  81,  68],
#          [ 35,  81,  68],
#          [ 34,  80,  67],
#          ...,
#          [124, 147, 155],
#          [124, 147, 155],
#          [124, 147, 155]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/538438_5_2_png.rf.a01dbe54ed6d85f492f25265f5d2362c.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.9131049998104572, 'inference': 151.24403899972094, 'postprocess': 5.033346998970956},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[230, 255, 251],
#          [230, 254, 252],
#          [228, 253, 255],
#          ...,
#          [134, 116, 117],
#          [139, 121, 122],
#          [138, 120, 121]],
#
#         [[232, 255, 250],
#          [230, 255, 251],
#          [230, 253, 255],
#          ...,
#          [177, 159, 160],
#          [178, 157, 159],
#          [173, 155, 156]],
#
#         [[233, 255, 247],
#          [233, 255, 248],
#          [233, 254, 252],
#          ...,
#          [180, 159, 161],
#          [181, 159, 161],
#          [176, 155, 157]],
#
#         ...,
#
#         [[ 36,  77,  49],
#          [ 36,  77,  49],
#          [ 36,  77,  49],
#          ...,
#          [ 52,  79,  63],
#          [ 45,  71,  55],
#          [ 21,  48,  32]],
#
#         [[ 36,  76,  48],
#          [ 36,  76,  48],
#          [ 36,  76,  48],
#          ...,
#          [ 48,  77,  62],
#          [ 44,  70,  56],
#          [ 22,  51,  36]],
#
#         [[ 36,  76,  48],
#          [ 35,  75,  47],
#          [ 35,  75,  47],
#          ...,
#          [ 44,  73,  58],
#          [ 39,  68,  53],
#          [ 21,  50,  35]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/573e61_1_9_png.rf.8da2275498160aa3f377ff7045d294b8.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.9500029997725505, 'inference': 151.23069400033273, 'postprocess': 4.524539999692934},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[173, 165, 175],
#          [221, 216, 225],
#          [117, 111, 122],
#          ...,
#          [ 92,  84,  91],
#          [ 80,  73,  78],
#          [ 75,  68,  73]],
#
#         [[122, 114, 125],
#          [153, 147, 158],
#          [125, 121, 132],
#          ...,
#          [ 66,  58,  65],
#          [ 62,  54,  61],
#          [ 65,  58,  63]],
#
#         [[ 99,  92, 105],
#          [107, 103, 115],
#          [ 98,  94, 106],
#          ...,
#          [ 59,  51,  58],
#          [ 59,  51,  58],
#          [ 66,  58,  65]],
#
#         ...,
#
#         [[127, 118, 114],
#          [110, 102,  95],
#          [102,  92,  85],
#          ...,
#          [ 69,  97,  78],
#          [ 63,  91,  72],
#          [ 59,  87,  68]],
#
#         [[167, 163, 152],
#          [174, 168, 155],
#          [162, 155, 140],
#          ...,
#          [ 69,  96,  80],
#          [ 64,  91,  75],
#          [ 59,  86,  70]],
#
#         [[202, 199, 184],
#          [202, 200, 182],
#          [160, 153, 136],
#          ...,
#          [ 64,  91,  75],
#          [ 62,  88,  74],
#          [ 61,  87,  73]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/573e61_9_6_png.rf.1d9472b7b7c4a74a93a926c6047cd2af.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.7730100011685863, 'inference': 152.05639299892937, 'postprocess': 4.858193000472966},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 28,  31,  29],
#          [ 27,  30,  28],
#          [ 27,  30,  28],
#          ...,
#          [ 70,  72,  60],
#          [ 68,  71,  56],
#          [ 68,  71,  55]],
#
#         [[ 30,  33,  31],
#          [ 29,  32,  30],
#          [ 27,  30,  28],
#          ...,
#          [ 68,  70,  58],
#          [ 69,  72,  57],
#          [ 69,  72,  56]],
#
#         [[ 36,  39,  37],
#          [ 34,  37,  35],
#          [ 30,  33,  31],
#          ...,
#          [ 69,  70,  60],
#          [ 71,  73,  61],
#          [ 72,  75,  60]],
#
#         ...,
#
#         [[ 77,  97, 102],
#          [ 94, 114, 119],
#          [109, 129, 134],
#          ...,
#          [ 28,  44,  50],
#          [ 25,  41,  47],
#          [ 20,  36,  42]],
#
#         [[149, 168, 173],
#          [135, 154, 159],
#          [134, 153, 158],
#          ...,
#          [ 22,  36,  42],
#          [ 22,  36,  42],
#          [ 22,  36,  42]],
#
#         [[110, 129, 134],
#          [ 91, 110, 115],
#          [104, 123, 128],
#          ...,
#          [ 16,  30,  36],
#          [ 19,  33,  39],
#          [ 21,  35,  41]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_1_10_png.rf.cabe7f0ac5c75671f5cd8ebf2dea597a.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.875779999361839, 'inference': 152.17378300076234, 'postprocess': 4.736227001558291},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[102, 128, 128],
#          [186, 212, 212],
#          [190, 214, 214],
#          ...,
#          [ 18,  22,  23],
#          [ 16,  20,  21],
#          [ 17,  21,  22]],
#
#         [[ 27,  53,  53],
#          [ 76, 102, 102],
#          [108, 132, 132],
#          ...,
#          [ 18,  22,  23],
#          [ 16,  20,  21],
#          [ 17,  21,  22]],
#
#         [[ 19,  43,  41],
#          [ 15,  39,  37],
#          [ 34,  56,  54],
#          ...,
#          [ 18,  22,  23],
#          [ 17,  21,  22],
#          [ 18,  22,  23]],
#
#         ...,
#
#         [[  8,  14,  21],
#          [ 10,  16,  23],
#          [ 11,  17,  24],
#          ...,
#          [ 39,  76,  68],
#          [ 39,  76,  68],
#          [ 39,  76,  68]],
#
#         [[  5,   8,  16],
#          [  6,   9,  17],
#          [  8,  11,  19],
#          ...,
#          [ 39,  73,  66],
#          [ 40,  74,  67],
#          [ 40,  74,  67]],
#
#         [[  4,   7,  15],
#          [  5,   8,  16],
#          [  6,   9,  17],
#          ...,
#          [ 38,  72,  65],
#          [ 39,  73,  66],
#          [ 39,  73,  66]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_7_4_png.rf.eb099bcea99cf692889ab77d9f679b5a.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.9701679997961037, 'inference': 152.00318600000173, 'postprocess': 4.903488001218648},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 34,  35,  39],
#          [ 29,  30,  34],
#          [ 31,  33,  34],
#          ...,
#          [ 59,  77,  94],
#          [ 53,  72,  87],
#          [ 62,  81,  96]],
#
#         [[ 33,  34,  38],
#          [ 29,  30,  34],
#          [ 30,  32,  33],
#          ...,
#          [ 66,  82,  98],
#          [ 65,  81,  97],
#          [ 78,  94, 110]],
#
#         [[ 32,  34,  35],
#          [ 29,  31,  32],
#          [ 29,  31,  32],
#          ...,
#          [ 64,  79,  95],
#          [ 67,  82,  98],
#          [ 70,  86,  99]],
#
#         ...,
#
#         [[ 45,  40,  41],
#          [ 40,  38,  38],
#          [ 38,  43,  41],
#          ...,
#          [ 23,  31,  31],
#          [ 14,  21,  24],
#          [ 37,  44,  47]],
#
#         [[ 45,  40,  41],
#          [ 39,  37,  37],
#          [ 38,  43,  41],
#          ...,
#          [ 17,  25,  25],
#          [ 21,  28,  31],
#          [ 21,  28,  31]],
#
#         [[ 45,  40,  41],
#          [ 39,  37,  37],
#          [ 37,  42,  40],
#          ...,
#          [  4,  12,  12],
#          [ 33,  40,  43],
#          [ 16,  23,  26]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_9_9_png.rf.66884f75e67df321142d2600f1c7a3f1.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.055155000969535, 'inference': 151.42636600103287, 'postprocess': 4.59908499942685},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[  0,  43,  46],
#          [  0,  29,  32],
#          [ 10,  45,  49],
#          ...,
#          [ 30,  71,  74],
#          [ 33,  73,  78],
#          [ 24,  66,  71]],
#
#         [[ 40,  83,  86],
#          [ 20,  58,  62],
#          [ 37,  72,  76],
#          ...,
#          [ 27,  63,  69],
#          [ 34,  71,  79],
#          [ 32,  71,  79]],
#
#         [[ 71, 109, 111],
#          [ 37,  72,  75],
#          [ 55,  86,  89],
#          ...,
#          [ 38,  69,  78],
#          [ 43,  75,  86],
#          [ 38,  73,  83]],
#
#         ...,
#
#         [[105, 233, 232],
#          [105, 233, 232],
#          [105, 233, 232],
#          ...,
#          [ 17, 114, 124],
#          [ 12, 109, 119],
#          [ 20, 117, 127]],
#
#         [[102, 232, 231],
#          [102, 232, 231],
#          [103, 233, 232],
#          ...,
#          [ 20, 117, 127],
#          [ 29, 124, 134],
#          [ 32, 127, 137]],
#
#         [[102, 232, 231],
#          [102, 232, 231],
#          [102, 232, 231],
#          ...,
#          [ 55, 152, 162],
#          [ 75, 170, 180],
#          [ 72, 167, 177]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_3_10_png.rf.00e76ea90f2abc32e09334c3194c7c49.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.9119899993238505, 'inference': 151.6208609991736, 'postprocess': 4.784033000760246},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 21,  25,  26],
#          [ 22,  26,  27],
#          [ 23,  27,  28],
#          ...,
#          [ 11,  24,  22],
#          [ 11,  24,  22],
#          [ 16,  29,  27]],
#
#         [[ 23,  27,  28],
#          [ 23,  27,  28],
#          [ 22,  26,  27],
#          ...,
#          [ 15,  26,  24],
#          [ 17,  28,  26],
#          [ 24,  35,  33]],
#
#         [[ 24,  28,  29],
#          [ 23,  27,  28],
#          [ 21,  25,  26],
#          ...,
#          [ 22,  31,  28],
#          [ 25,  33,  32],
#          [ 32,  40,  39]],
#
#         ...,
#
#         [[ 87, 204, 195],
#          [ 87, 204, 195],
#          [ 87, 203, 196],
#          ...,
#          [ 25,  57,  56],
#          [ 37,  69,  68],
#          [ 44,  78,  77]],
#
#         [[ 86, 203, 194],
#          [ 86, 203, 194],
#          [ 87, 204, 195],
#          ...,
#          [ 39,  75,  75],
#          [ 33,  69,  69],
#          [ 28,  66,  66]],
#
#         [[ 85, 202, 193],
#          [ 86, 203, 194],
#          [ 87, 204, 195],
#          ...,
#          [ 30,  68,  68],
#          [ 31,  69,  69],
#          [ 31,  71,  70]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_3_3_png.rf.f62ed4e82697a2930b4d9bdd6ece0f9b.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 3.8238889992499026, 'inference': 151.8512600014219, 'postprocess': 4.768926999531686},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[39, 58, 55],
#          [43, 64, 61],
#          [50, 74, 72],
#          ...,
#          [12, 25, 23],
#          [14, 27, 25],
#          [18, 31, 29]],
#
#         [[34, 53, 50],
#          [38, 59, 56],
#          [45, 69, 67],
#          ...,
#          [19, 32, 30],
#          [20, 33, 31],
#          [23, 36, 34]],
#
#         [[18, 37, 34],
#          [25, 46, 43],
#          [34, 56, 54],
#          ...,
#          [27, 40, 38],
#          [27, 40, 38],
#          [27, 40, 38]],
#
#         ...,
#
#         [[51, 96, 79],
#          [51, 96, 79],
#          [52, 96, 79],
#          ...,
#          [ 4, 26, 21],
#          [12, 13,  9],
#          [37, 28, 24]],
#
#         [[50, 98, 80],
#          [50, 98, 80],
#          [52, 97, 80],
#          ...,
#          [ 0, 18,  7],
#          [18, 23, 14],
#          [35, 26, 17]],
#
#         [[51, 99, 81],
#          [51, 99, 81],
#          [53, 98, 81],
#          ...,
#          [ 0, 21,  6],
#          [32, 38, 27],
#          [27, 17,  7]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_7_8_png.rf.30060820d1e9b058ac2c519039d057aa.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.272106998541858, 'inference': 152.62739500030875, 'postprocess': 4.6567219997086795},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[  6,  12,  23],
#          [  6,  12,  23],
#          [  6,  12,  23],
#          ...,
#          [ 31,  42,  56],
#          [ 31,  43,  55],
#          [ 29,  41,  53]],
#
#         [[  8,  14,  25],
#          [  8,  14,  25],
#          [  8,  14,  25],
#          ...,
#          [ 31,  41,  58],
#          [ 34,  44,  61],
#          [ 35,  46,  60]],
#
#         [[ 12,  18,  31],
#          [ 12,  18,  31],
#          [ 12,  18,  31],
#          ...,
#          [ 36,  45,  65],
#          [ 37,  46,  66],
#          [ 38,  47,  67]],
#
#         ...,
#
#         [[ 87,  90, 104],
#          [ 98, 101, 115],
#          [ 81,  83, 101],
#          ...,
#          [233, 233, 255],
#          [215, 213, 235],
#          [133, 131, 150]],
#
#         [[ 95,  97, 108],
#          [ 98, 100, 111],
#          [ 78,  78,  94],
#          ...,
#          [232, 231, 255],
#          [244, 242, 255],
#          [164, 165, 179]],
#
#         [[ 91,  93, 103],
#          [ 89,  91, 102],
#          [ 68,  69,  83],
#          ...,
#          [232, 229, 255],
#          [234, 235, 255],
#          [201, 203, 214]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/a9f16c_2_10_png.rf.7a5ffdc0b8955577fe953b92a257078b.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.118983999433112, 'inference': 152.2830760004581, 'postprocess': 4.67365100121242},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 25,  33,  50],
#          [ 25,  33,  50],
#          [ 25,  33,  50],
#          ...,
#          [ 51,  96,  93],
#          [ 52,  91,  93],
#          [ 50,  89,  91]],
#
#         [[ 27,  35,  52],
#          [ 27,  36,  50],
#          [ 27,  35,  52],
#          ...,
#          [ 69, 115, 109],
#          [ 70, 110, 108],
#          [ 68, 108, 106]],
#
#         [[ 30,  39,  53],
#          [ 30,  39,  52],
#          [ 30,  39,  53],
#          ...,
#          [ 78, 126, 114],
#          [ 79, 122, 111],
#          [ 77, 120, 111]],
#
#         ...,
#
#         [[103, 117, 123],
#          [105, 119, 125],
#          [110, 122, 128],
#          ...,
#          [146, 159, 167],
#          [148, 160, 170],
#          [149, 161, 171]],
#
#         [[107, 121, 127],
#          [109, 123, 129],
#          [111, 125, 131],
#          ...,
#          [136, 151, 160],
#          [137, 152, 161],
#          [137, 152, 161]],
#
#         [[111, 125, 131],
#          [113, 127, 133],
#          [115, 129, 135],
#          ...,
#          [127, 142, 151],
#          [124, 139, 148],
#          [123, 138, 147]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/a9f16c_2_9_png.rf.3d70706303f110aedc833f5c8912b233.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict'
#  speed: {'preprocess': 4.112364000320667, 'inference': 151.08307499940565, 'postprocess': 5.021365001084632}]

# %%
# Show balls only
trained_model.predict(source=TEST_IMGS_PATH,
              conf=0.4,
              save=True,
              classes = [0],
              project = RESULTS_PATH)
# Out:
# image 1/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/08fd33_3_6_png.rf.261781c58b95436fb40e6afc0495bc57.jpg: 1024x1024 1 ball, 157.7ms
# image 2/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/08fd33_9_3_png.rf.20ff5bcc914d7f607cf9425c73da679c.jpg: 1024x1024 (no detections), 155.8ms
# image 3/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/40cd38_7_6_png.rf.3e49856b19208cd7b616cd826a793f08.jpg: 1024x1024 (no detections), 151.4ms
# image 4/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/42ba34_1_5_png.rf.e530a34d1588130dae6f6cba815688ce.jpg: 1024x1024 1 ball, 151.6ms
# image 5/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/42ba34_5_5_png.rf.4153d27549bb9aad06d11a54c1ea3dc3.jpg: 1024x1024 (no detections), 153.0ms
# image 6/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_4_png.rf.746881815061da6082d636894dbb523f.jpg: 1024x1024 (no detections), 153.7ms
# image 7/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_6_png.rf.83c3cdc332120b9da3c017083daaa489.jpg: 1024x1024 (no detections), 153.5ms
# image 8/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_8_png.rf.3d4f596483faaa1d25084d5317ea71fd.jpg: 1024x1024 1 ball, 152.4ms
# image 9/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_3_6_png.rf.00d0b5f62d7a263ec314a7f6feca6936.jpg: 1024x1024 (no detections), 153.2ms
# image 10/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_3_9_png.rf.1185713c3c0f110b6daf1176d5743755.jpg: 1024x1024 1 ball, 152.7ms
# image 11/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_5_1_png.rf.79a7fb518f57a14552c4a2e27c7d287e.jpg: 1024x1024 1 ball, 153.6ms
# image 12/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_9_3_png.rf.77259c789c1e3777d5dbc1f55e6cb22f.jpg: 1024x1024 (no detections), 153.2ms
# image 13/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_9_4_png.rf.c45fd1178606ed8fe6c0acaf12f59f8b.jpg: 1024x1024 1 ball, 152.3ms
# image 14/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/538438_3_6_png.rf.3394ec92531a1a42f7a73ee1050ae63a.jpg: 1024x1024 (no detections), 153.2ms
# image 15/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/538438_5_2_png.rf.a01dbe54ed6d85f492f25265f5d2362c.jpg: 1024x1024 (no detections), 151.6ms
# image 16/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/573e61_1_9_png.rf.8da2275498160aa3f377ff7045d294b8.jpg: 1024x1024 (no detections), 151.7ms
# image 17/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/573e61_9_6_png.rf.1d9472b7b7c4a74a93a926c6047cd2af.jpg: 1024x1024 (no detections), 151.6ms
# image 18/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_1_10_png.rf.cabe7f0ac5c75671f5cd8ebf2dea597a.jpg: 1024x1024 (no detections), 151.4ms
# image 19/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_7_4_png.rf.eb099bcea99cf692889ab77d9f679b5a.jpg: 1024x1024 (no detections), 151.2ms
# image 20/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_9_9_png.rf.66884f75e67df321142d2600f1c7a3f1.jpg: 1024x1024 (no detections), 151.8ms
# image 21/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_3_10_png.rf.00e76ea90f2abc32e09334c3194c7c49.jpg: 1024x1024 1 ball, 152.4ms
# image 22/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_3_3_png.rf.f62ed4e82697a2930b4d9bdd6ece0f9b.jpg: 1024x1024 (no detections), 153.2ms
# image 23/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_7_8_png.rf.30060820d1e9b058ac2c519039d057aa.jpg: 1024x1024 1 ball, 153.0ms
# image 24/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/a9f16c_2_10_png.rf.7a5ffdc0b8955577fe953b92a257078b.jpg: 1024x1024 1 ball, 152.8ms
# image 25/25 /home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/a9f16c_2_9_png.rf.3d70706303f110aedc833f5c8912b233.jpg: 1024x1024 (no detections), 153.2ms
# Speed: 4.7ms preprocess, 152.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[255, 253, 249],
#          [255, 254, 250],
#          [254, 255, 251],
#          ...,
#          [106,  94,  76],
#          [122, 110,  92],
#          [113, 101,  83]],
#
#         [[255, 254, 250],
#          [255, 254, 250],
#          [254, 255, 251],
#          ...,
#          [106,  94,  76],
#          [128, 116,  98],
#          [116, 104,  86]],
#
#         [[255, 254, 250],
#          [253, 254, 250],
#          [252, 255, 251],
#          ...,
#          [140, 130, 113],
#          [136, 126, 109],
#          [ 94,  84,  67]],
#
#         ...,
#
#         [[145, 147, 117],
#          [139, 141, 112],
#          [147, 144, 116],
#          ...,
#          [ 55,  53,  45],
#          [105, 103,  95],
#          [102, 100,  92]],
#
#         [[146, 148, 119],
#          [140, 142, 113],
#          [146, 142, 117],
#          ...,
#          [ 60,  58,  50],
#          [110, 108, 100],
#          [107, 105,  97]],
#
#         [[145, 147, 118],
#          [138, 140, 111],
#          [144, 140, 116],
#          ...,
#          [ 74,  72,  64],
#          [108, 106,  98],
#          [ 91,  89,  81]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/08fd33_3_6_png.rf.261781c58b95436fb40e6afc0495bc57.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 20.806472000913345, 'inference': 157.70231200076523, 'postprocess': 0.9078300008695805},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[125, 111,  99],
#          [124, 110,  98],
#          [122, 108,  96],
#          ...,
#          [ 74,  57,  54],
#          [ 71,  52,  47],
#          [ 85,  66,  61]],
#
#         [[127, 113, 101],
#          [129, 115, 103],
#          [127, 113, 101],
#          ...,
#          [ 71,  54,  51],
#          [ 62,  43,  38],
#          [ 81,  62,  57]],
#
#         [[114, 100,  88],
#          [117, 103,  91],
#          [115, 103,  91],
#          ...,
#          [ 78,  62,  56],
#          [ 72,  56,  50],
#          [104,  88,  82]],
#
#         ...,
#
#         [[ 83, 107,  89],
#          [ 81, 107,  89],
#          [ 82, 105,  90],
#          ...,
#          [ 72,  64,  64],
#          [ 69,  61,  62],
#          [ 65,  57,  58]],
#
#         [[ 78, 104,  88],
#          [ 76, 103,  87],
#          [ 76, 102,  86],
#          ...,
#          [ 65,  59,  60],
#          [ 56,  49,  52],
#          [ 58,  51,  54]],
#
#         [[ 77, 104,  88],
#          [ 77, 104,  88],
#          [ 76, 103,  87],
#          ...,
#          [ 63,  57,  58],
#          [ 52,  45,  50],
#          [ 65,  58,  63]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/08fd33_9_3_png.rf.20ff5bcc914d7f607cf9425c73da679c.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.159862000960857, 'inference': 155.79684200019983, 'postprocess': 1.0606800005916739},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[107, 115,  98],
#          [103, 111,  94],
#          [106, 115,  95],
#          ...,
#          [255, 250, 177],
#          [255, 248, 178],
#          [255, 248, 178]],
#
#         [[112, 119, 106],
#          [120, 127, 114],
#          [107, 114,  99],
#          ...,
#          [215, 207, 137],
#          [213, 202, 134],
#          [209, 200, 132]],
#
#         [[ 97, 102, 100],
#          [101, 107, 102],
#          [ 98, 105,  98],
#          ...,
#          [161, 152,  88],
#          [160, 150,  86],
#          [158, 149,  85]],
#
#         ...,
#
#         [[ 44,  59,  68],
#          [ 27,  42,  51],
#          [ 49,  61,  71],
#          ...,
#          [ 51,  49,  48],
#          [ 51,  50,  52],
#          [ 53,  52,  54]],
#
#         [[ 43,  57,  69],
#          [ 33,  47,  59],
#          [ 44,  58,  70],
#          ...,
#          [ 53,  46,  49],
#          [ 63,  56,  63],
#          [ 60,  55,  64]],
#
#         [[ 37,  51,  63],
#          [ 34,  48,  60],
#          [ 40,  53,  67],
#          ...,
#          [ 53,  46,  51],
#          [ 63,  53,  65],
#          [ 50,  41,  54]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/40cd38_7_6_png.rf.3e49856b19208cd7b616cd826a793f08.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.329662000600365, 'inference': 151.42085700063035, 'postprocess': 0.7234570002765395},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[109, 114,  83],
#          [128, 133, 101],
#          [153, 158, 126],
#          ...,
#          [149, 167, 150],
#          [140, 159, 140],
#          [131, 150, 131]],
#
#         [[118, 121,  95],
#          [112, 116,  87],
#          [125, 130,  99],
#          ...,
#          [153, 171, 154],
#          [147, 165, 148],
#          [141, 160, 141]],
#
#         [[131, 133, 113],
#          [122, 125, 103],
#          [132, 136, 111],
#          ...,
#          [150, 165, 151],
#          [145, 162, 148],
#          [141, 159, 142]],
#
#         ...,
#
#         [[ 62,  67,  66],
#          [ 62,  67,  66],
#          [ 42,  45,  43],
#          ...,
#          [ 65,  66,  64],
#          [ 68,  68,  62],
#          [ 64,  65,  55]],
#
#         [[ 59,  64,  62],
#          [ 63,  68,  66],
#          [ 42,  45,  43],
#          ...,
#          [ 55,  56,  54],
#          [ 59,  59,  53],
#          [ 62,  63,  54]],
#
#         [[ 54,  59,  57],
#          [ 63,  68,  66],
#          [ 44,  47,  45],
#          ...,
#          [ 52,  52,  52],
#          [ 57,  57,  51],
#          [ 66,  67,  58]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/42ba34_1_5_png.rf.e530a34d1588130dae6f6cba815688ce.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.322296001191717, 'inference': 151.5684109999711, 'postprocess': 0.9928409999702126},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 79,  53,  53],
#          [ 68,  43,  41],
#          [128, 106, 101],
#          ...,
#          [155, 141, 143],
#          [156, 142, 144],
#          [157, 143, 145]],
#
#         [[ 72,  46,  46],
#          [ 90,  67,  65],
#          [148, 126, 120],
#          ...,
#          [ 97,  84,  86],
#          [ 99,  86,  88],
#          [100,  87,  89]],
#
#         [[101,  78,  76],
#          [ 95,  75,  70],
#          [152, 133, 125],
#          ...,
#          [ 49,  38,  40],
#          [ 51,  40,  42],
#          [ 52,  41,  43]],
#
#         ...,
#
#         [[ 44,  97,  53],
#          [ 44,  97,  53],
#          [ 44,  97,  53],
#          ...,
#          [ 87,  93,  70],
#          [ 87,  93,  70],
#          [ 88,  94,  71]],
#
#         [[ 44,  97,  53],
#          [ 44,  97,  53],
#          [ 44,  97,  53],
#          ...,
#          [ 86,  91,  70],
#          [ 86,  91,  70],
#          [ 87,  92,  71]],
#
#         [[ 44,  97,  53],
#          [ 44,  97,  53],
#          [ 44,  97,  53],
#          ...,
#          [ 85,  90,  69],
#          [ 86,  91,  70],
#          [ 87,  92,  71]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/42ba34_5_5_png.rf.4153d27549bb9aad06d11a54c1ea3dc3.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.047484000693657, 'inference': 152.96185899933334, 'postprocess': 0.8150140001816908},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 30,  35,  34],
#          [ 31,  36,  35],
#          [ 32,  37,  36],
#          ...,
#          [ 53,  66,  68],
#          [ 39,  54,  56],
#          [ 22,  37,  39]],
#
#         [[ 30,  35,  34],
#          [ 30,  35,  34],
#          [ 30,  35,  34],
#          ...,
#          [ 41,  56,  58],
#          [ 33,  48,  50],
#          [ 21,  36,  38]],
#
#         [[ 29,  34,  33],
#          [ 29,  34,  33],
#          [ 28,  33,  32],
#          ...,
#          [ 35,  53,  54],
#          [ 32,  50,  51],
#          [ 27,  45,  46]],
#
#         ...,
#
#         [[ 58, 122, 127],
#          [ 84, 147, 151],
#          [ 85, 141, 146],
#          ...,
#          [170, 155, 159],
#          [182, 165, 169],
#          [186, 171, 175]],
#
#         [[ 37, 107, 114],
#          [ 66, 134, 139],
#          [ 69, 132, 136],
#          ...,
#          [165, 147, 154],
#          [166, 145, 153],
#          [163, 145, 152]],
#
#         [[ 29, 101, 108],
#          [ 52, 123, 127],
#          [ 52, 116, 121],
#          ...,
#          [183, 162, 170],
#          [177, 156, 164],
#          [169, 148, 156]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_4_png.rf.746881815061da6082d636894dbb523f.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.080607999640051, 'inference': 153.7240349989588, 'postprocess': 0.791727001342224},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 30,  43,  45],
#          [ 40,  53,  55],
#          [ 31,  44,  46],
#          ...,
#          [ 40,  45,  43],
#          [ 39,  46,  41],
#          [ 39,  46,  41]],
#
#         [[ 21,  34,  36],
#          [ 29,  42,  44],
#          [ 22,  35,  37],
#          ...,
#          [ 39,  44,  42],
#          [ 38,  45,  40],
#          [ 38,  45,  40]],
#
#         [[ 21,  34,  36],
#          [ 27,  40,  42],
#          [ 23,  35,  37],
#          ...,
#          [ 41,  46,  44],
#          [ 39,  46,  41],
#          [ 39,  46,  41]],
#
#         ...,
#
#         [[ 65, 114, 128],
#          [ 75, 122, 136],
#          [ 62, 105, 120],
#          ...,
#          [ 27,  38,  42],
#          [ 35,  47,  49],
#          [ 43,  53,  53]],
#
#         [[ 28,  66,  84],
#          [ 23,  59,  77],
#          [ 22,  52,  71],
#          ...,
#          [ 37,  46,  49],
#          [ 43,  51,  51],
#          [ 34,  42,  41]],
#
#         [[ 25,  58,  77],
#          [ 30,  62,  81],
#          [ 33,  57,  77],
#          ...,
#          [ 54,  64,  64],
#          [ 64,  69,  70],
#          [ 46,  52,  51]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_6_png.rf.83c3cdc332120b9da3c017083daaa489.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.930143999241409, 'inference': 153.45692499977304, 'postprocess': 0.7464619993697852},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 42,  65,  81],
#          [ 51,  74,  90],
#          [ 55,  76,  91],
#          ...,
#          [ 18,  22,  23],
#          [ 18,  23,  26],
#          [ 19,  24,  27]],
#
#         [[ 62,  82,  99],
#          [ 50,  71,  86],
#          [ 46,  67,  82],
#          ...,
#          [ 20,  24,  25],
#          [ 20,  25,  28],
#          [ 21,  26,  29]],
#
#         [[ 59,  78,  93],
#          [ 31,  50,  63],
#          [ 28,  47,  60],
#          ...,
#          [ 23,  27,  28],
#          [ 21,  26,  29],
#          [ 21,  26,  29]],
#
#         ...,
#
#         [[ 80, 125, 108],
#          [ 81, 129, 111],
#          [ 83, 130, 114],
#          ...,
#          [ 25,  41,  53],
#          [ 25,  42,  55],
#          [ 10,  29,  44]],
#
#         [[ 66, 118, 101],
#          [ 66, 118, 101],
#          [ 63, 114, 100],
#          ...,
#          [ 26,  42,  54],
#          [ 26,  43,  56],
#          [  6,  25,  40]],
#
#         [[ 70, 124, 107],
#          [ 66, 120, 103],
#          [ 60, 115, 100],
#          ...,
#          [ 20,  36,  48],
#          [ 12,  29,  42],
#          [ 17,  36,  51]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_1_8_png.rf.3d4f596483faaa1d25084d5317ea71fd.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.269810000550933, 'inference': 152.36268099943118, 'postprocess': 0.8657769994897535},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 25,  29,  30],
#          [  9,  13,  14],
#          [ 30,  34,  35],
#          ...,
#          [ 22,  21,  23],
#          [ 24,  21,  23],
#          [ 26,  23,  25]],
#
#         [[ 28,  32,  33],
#          [ 15,  19,  20],
#          [ 36,  40,  41],
#          ...,
#          [ 17,  16,  18],
#          [ 23,  22,  24],
#          [ 31,  30,  32]],
#
#         [[ 28,  32,  33],
#          [ 18,  22,  23],
#          [ 37,  41,  42],
#          ...,
#          [ 16,  18,  19],
#          [ 26,  28,  29],
#          [ 40,  42,  43]],
#
#         ...,
#
#         [[  9,   9,   9],
#          [  8,   8,   8],
#          [  7,   7,   7],
#          ...,
#          [137, 218, 221],
#          [110, 187, 189],
#          [ 49, 127, 126]],
#
#         [[  9,   9,   9],
#          [  8,   8,   8],
#          [  7,   7,   7],
#          ...,
#          [136, 221, 223],
#          [122, 208, 208],
#          [ 90, 173, 174]],
#
#         [[  9,   9,   9],
#          [  8,   8,   8],
#          [  7,   7,   7],
#          ...,
#          [129, 219, 220],
#          [133, 220, 222],
#          [138, 226, 226]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_3_6_png.rf.00d0b5f62d7a263ec314a7f6feca6936.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.044862000228022, 'inference': 153.19228699991072, 'postprocess': 0.7126149994292064},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 25,  49,  39],
#          [ 31,  52,  43],
#          [ 35,  53,  46],
#          ...,
#          [ 18,  22,  23],
#          [ 41,  45,  46],
#          [ 49,  53,  54]],
#
#         [[ 25,  49,  39],
#          [ 28,  49,  40],
#          [ 32,  50,  43],
#          ...,
#          [ 20,  24,  25],
#          [ 33,  37,  38],
#          [ 45,  49,  50]],
#
#         [[ 26,  49,  41],
#          [ 25,  46,  38],
#          [ 29,  47,  40],
#          ...,
#          [ 31,  36,  37],
#          [ 30,  35,  36],
#          [ 46,  51,  52]],
#
#         ...,
#
#         [[ 24,  33,  36],
#          [ 21,  30,  33],
#          [ 17,  29,  31],
#          ...,
#          [ 16, 109, 100],
#          [ 19, 109, 103],
#          [ 18, 111, 102]],
#
#         [[ 20,  28,  28],
#          [ 18,  28,  28],
#          [ 20,  30,  30],
#          ...,
#          [ 43, 143, 131],
#          [ 34, 131, 121],
#          [ 25, 125, 113]],
#
#         [[ 20,  28,  28],
#          [ 22,  30,  30],
#          [ 24,  34,  34],
#          ...,
#          [ 93, 195, 183],
#          [ 73, 175, 163],
#          [ 59, 161, 149]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_3_9_png.rf.1185713c3c0f110b6daf1176d5743755.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.127792000872432, 'inference': 152.71324700006517, 'postprocess': 0.8352550012205029},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[12, 20, 19],
#          [20, 28, 27],
#          [25, 33, 32],
#          ...,
#          [74, 84, 72],
#          [66, 76, 63],
#          [58, 68, 55]],
#
#         [[24, 32, 31],
#          [28, 36, 35],
#          [29, 37, 36],
#          ...,
#          [73, 83, 70],
#          [42, 52, 39],
#          [29, 39, 26]],
#
#         [[33, 41, 40],
#          [34, 42, 41],
#          [29, 37, 36],
#          ...,
#          [47, 56, 43],
#          [25, 34, 21],
#          [28, 38, 22]],
#
#         ...,
#
#         [[34, 53, 60],
#          [35, 55, 60],
#          [40, 58, 65],
#          ...,
#          [48, 61, 75],
#          [44, 58, 76],
#          [46, 60, 78]],
#
#         [[42, 64, 69],
#          [44, 65, 67],
#          [45, 64, 69],
#          ...,
#          [45, 58, 72],
#          [36, 50, 68],
#          [40, 55, 74]],
#
#         [[35, 58, 60],
#          [27, 50, 52],
#          [23, 42, 45],
#          ...,
#          [49, 62, 78],
#          [36, 50, 68],
#          [43, 58, 77]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_5_1_png.rf.79a7fb518f57a14552c4a2e27c7d287e.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.1877610001392895, 'inference': 153.59421500033932, 'postprocess': 0.810830999398604},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[15, 20, 18],
#          [15, 20, 18],
#          [14, 19, 17],
#          ...,
#          [22, 27, 26],
#          [25, 29, 30],
#          [28, 32, 33]],
#
#         [[15, 20, 18],
#          [15, 20, 18],
#          [14, 19, 17],
#          ...,
#          [22, 26, 27],
#          [24, 28, 29],
#          [26, 30, 31]],
#
#         [[15, 20, 18],
#          [15, 20, 18],
#          [14, 19, 17],
#          ...,
#          [22, 25, 29],
#          [22, 25, 29],
#          [24, 27, 31]],
#
#         ...,
#
#         [[17, 28, 26],
#          [19, 30, 28],
#          [22, 30, 29],
#          ...,
#          [28, 44, 51],
#          [27, 45, 52],
#          [27, 45, 52]],
#
#         [[17, 28, 26],
#          [18, 29, 27],
#          [23, 31, 30],
#          ...,
#          [25, 41, 48],
#          [23, 41, 48],
#          [24, 42, 49]],
#
#         [[16, 27, 25],
#          [18, 29, 27],
#          [23, 31, 30],
#          ...,
#          [23, 39, 46],
#          [20, 38, 45],
#          [21, 39, 46]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_9_3_png.rf.77259c789c1e3777d5dbc1f55e6cb22f.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.913026999725844, 'inference': 153.20767999946838, 'postprocess': 0.6484599998657359},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[21, 22, 20],
#          [19, 20, 18],
#          [17, 18, 16],
#          ...,
#          [25, 33, 22],
#          [26, 34, 23],
#          [27, 35, 24]],
#
#         [[21, 22, 20],
#          [19, 20, 18],
#          [17, 18, 16],
#          ...,
#          [25, 33, 23],
#          [26, 34, 24],
#          [27, 35, 25]],
#
#         [[21, 22, 20],
#          [19, 20, 18],
#          [17, 18, 16],
#          ...,
#          [24, 32, 25],
#          [25, 33, 26],
#          [25, 33, 26]],
#
#         ...,
#
#         [[21, 23, 11],
#          [25, 27, 15],
#          [30, 32, 20],
#          ...,
#          [ 0, 16,  5],
#          [ 4, 19, 11],
#          [ 8, 21, 13]],
#
#         [[21, 23, 11],
#          [26, 28, 16],
#          [31, 33, 21],
#          ...,
#          [ 5, 28, 14],
#          [ 7, 27, 15],
#          [ 7, 27, 15]],
#
#         [[16, 18,  6],
#          [21, 23, 11],
#          [26, 28, 16],
#          ...,
#          [42, 69, 53],
#          [21, 43, 31],
#          [ 6, 28, 16]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/4b770a_9_4_png.rf.c45fd1178606ed8fe6c0acaf12f59f8b.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.8293109992082464, 'inference': 152.34735299964086, 'postprocess': 0.8356579983228585},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 47,  47,  47],
#          [ 48,  48,  48],
#          [ 50,  50,  50],
#          ...,
#          [ 46,  47,  45],
#          [ 45,  46,  44],
#          [ 45,  46,  44]],
#
#         [[ 46,  46,  46],
#          [ 46,  46,  46],
#          [ 47,  47,  47],
#          ...,
#          [ 46,  47,  45],
#          [ 45,  46,  44],
#          [ 45,  46,  44]],
#
#         [[ 46,  46,  46],
#          [ 47,  47,  47],
#          [ 47,  47,  47],
#          ...,
#          [ 45,  46,  44],
#          [ 45,  46,  44],
#          [ 45,  46,  44]],
#
#         ...,
#
#         [[ 42,  57,  59],
#          [ 42,  57,  59],
#          [ 43,  58,  60],
#          ...,
#          [ 93, 114, 115],
#          [ 93, 114, 115],
#          [ 93, 114, 115]],
#
#         [[ 46,  61,  63],
#          [ 46,  61,  63],
#          [ 46,  61,  63],
#          ...,
#          [106, 130, 130],
#          [106, 130, 130],
#          [106, 130, 130]],
#
#         [[ 45,  60,  62],
#          [ 45,  60,  62],
#          [ 44,  59,  61],
#          ...,
#          [130, 154, 154],
#          [129, 153, 153],
#          [129, 153, 153]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/538438_3_6_png.rf.3394ec92531a1a42f7a73ee1050ae63a.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.9632989992242074, 'inference': 153.19043299859914, 'postprocess': 0.7688349996897159},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[102, 114, 118],
#          [100, 112, 116],
#          [ 97, 109, 113],
#          ...,
#          [ 18,  23,  22],
#          [ 21,  26,  25],
#          [ 26,  31,  30]],
#
#         [[102, 114, 118],
#          [100, 112, 116],
#          [ 98, 110, 114],
#          ...,
#          [ 17,  22,  21],
#          [ 19,  24,  23],
#          [ 24,  29,  28]],
#
#         [[102, 114, 118],
#          [100, 112, 116],
#          [ 99, 111, 115],
#          ...,
#          [ 16,  21,  20],
#          [ 17,  22,  21],
#          [ 21,  26,  25]],
#
#         ...,
#
#         [[ 37,  83,  70],
#          [ 37,  83,  70],
#          [ 38,  84,  71],
#          ...,
#          [124, 147, 155],
#          [124, 147, 155],
#          [124, 147, 155]],
#
#         [[ 37,  83,  70],
#          [ 37,  83,  70],
#          [ 37,  83,  70],
#          ...,
#          [124, 147, 155],
#          [124, 147, 155],
#          [124, 147, 155]],
#
#         [[ 35,  81,  68],
#          [ 35,  81,  68],
#          [ 34,  80,  67],
#          ...,
#          [124, 147, 155],
#          [124, 147, 155],
#          [124, 147, 155]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/538438_5_2_png.rf.a01dbe54ed6d85f492f25265f5d2362c.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.9177269991341745, 'inference': 151.58108299874584, 'postprocess': 0.7099379999999655},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[230, 255, 251],
#          [230, 254, 252],
#          [228, 253, 255],
#          ...,
#          [134, 116, 117],
#          [139, 121, 122],
#          [138, 120, 121]],
#
#         [[232, 255, 250],
#          [230, 255, 251],
#          [230, 253, 255],
#          ...,
#          [177, 159, 160],
#          [178, 157, 159],
#          [173, 155, 156]],
#
#         [[233, 255, 247],
#          [233, 255, 248],
#          [233, 254, 252],
#          ...,
#          [180, 159, 161],
#          [181, 159, 161],
#          [176, 155, 157]],
#
#         ...,
#
#         [[ 36,  77,  49],
#          [ 36,  77,  49],
#          [ 36,  77,  49],
#          ...,
#          [ 52,  79,  63],
#          [ 45,  71,  55],
#          [ 21,  48,  32]],
#
#         [[ 36,  76,  48],
#          [ 36,  76,  48],
#          [ 36,  76,  48],
#          ...,
#          [ 48,  77,  62],
#          [ 44,  70,  56],
#          [ 22,  51,  36]],
#
#         [[ 36,  76,  48],
#          [ 35,  75,  47],
#          [ 35,  75,  47],
#          ...,
#          [ 44,  73,  58],
#          [ 39,  68,  53],
#          [ 21,  50,  35]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/573e61_1_9_png.rf.8da2275498160aa3f377ff7045d294b8.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.776235000259476, 'inference': 151.6603820000455, 'postprocess': 0.6567850014107535},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[173, 165, 175],
#          [221, 216, 225],
#          [117, 111, 122],
#          ...,
#          [ 92,  84,  91],
#          [ 80,  73,  78],
#          [ 75,  68,  73]],
#
#         [[122, 114, 125],
#          [153, 147, 158],
#          [125, 121, 132],
#          ...,
#          [ 66,  58,  65],
#          [ 62,  54,  61],
#          [ 65,  58,  63]],
#
#         [[ 99,  92, 105],
#          [107, 103, 115],
#          [ 98,  94, 106],
#          ...,
#          [ 59,  51,  58],
#          [ 59,  51,  58],
#          [ 66,  58,  65]],
#
#         ...,
#
#         [[127, 118, 114],
#          [110, 102,  95],
#          [102,  92,  85],
#          ...,
#          [ 69,  97,  78],
#          [ 63,  91,  72],
#          [ 59,  87,  68]],
#
#         [[167, 163, 152],
#          [174, 168, 155],
#          [162, 155, 140],
#          ...,
#          [ 69,  96,  80],
#          [ 64,  91,  75],
#          [ 59,  86,  70]],
#
#         [[202, 199, 184],
#          [202, 200, 182],
#          [160, 153, 136],
#          ...,
#          [ 64,  91,  75],
#          [ 62,  88,  74],
#          [ 61,  87,  73]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/573e61_9_6_png.rf.1d9472b7b7c4a74a93a926c6047cd2af.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.81793299857236, 'inference': 151.63830100027553, 'postprocess': 0.715445001333137},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 28,  31,  29],
#          [ 27,  30,  28],
#          [ 27,  30,  28],
#          ...,
#          [ 70,  72,  60],
#          [ 68,  71,  56],
#          [ 68,  71,  55]],
#
#         [[ 30,  33,  31],
#          [ 29,  32,  30],
#          [ 27,  30,  28],
#          ...,
#          [ 68,  70,  58],
#          [ 69,  72,  57],
#          [ 69,  72,  56]],
#
#         [[ 36,  39,  37],
#          [ 34,  37,  35],
#          [ 30,  33,  31],
#          ...,
#          [ 69,  70,  60],
#          [ 71,  73,  61],
#          [ 72,  75,  60]],
#
#         ...,
#
#         [[ 77,  97, 102],
#          [ 94, 114, 119],
#          [109, 129, 134],
#          ...,
#          [ 28,  44,  50],
#          [ 25,  41,  47],
#          [ 20,  36,  42]],
#
#         [[149, 168, 173],
#          [135, 154, 159],
#          [134, 153, 158],
#          ...,
#          [ 22,  36,  42],
#          [ 22,  36,  42],
#          [ 22,  36,  42]],
#
#         [[110, 129, 134],
#          [ 91, 110, 115],
#          [104, 123, 128],
#          ...,
#          [ 16,  30,  36],
#          [ 19,  33,  39],
#          [ 21,  35,  41]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_1_10_png.rf.cabe7f0ac5c75671f5cd8ebf2dea597a.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.7674049999623094, 'inference': 151.44384099949093, 'postprocess': 0.6980050002312055},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[102, 128, 128],
#          [186, 212, 212],
#          [190, 214, 214],
#          ...,
#          [ 18,  22,  23],
#          [ 16,  20,  21],
#          [ 17,  21,  22]],
#
#         [[ 27,  53,  53],
#          [ 76, 102, 102],
#          [108, 132, 132],
#          ...,
#          [ 18,  22,  23],
#          [ 16,  20,  21],
#          [ 17,  21,  22]],
#
#         [[ 19,  43,  41],
#          [ 15,  39,  37],
#          [ 34,  56,  54],
#          ...,
#          [ 18,  22,  23],
#          [ 17,  21,  22],
#          [ 18,  22,  23]],
#
#         ...,
#
#         [[  8,  14,  21],
#          [ 10,  16,  23],
#          [ 11,  17,  24],
#          ...,
#          [ 39,  76,  68],
#          [ 39,  76,  68],
#          [ 39,  76,  68]],
#
#         [[  5,   8,  16],
#          [  6,   9,  17],
#          [  8,  11,  19],
#          ...,
#          [ 39,  73,  66],
#          [ 40,  74,  67],
#          [ 40,  74,  67]],
#
#         [[  4,   7,  15],
#          [  5,   8,  16],
#          [  6,   9,  17],
#          ...,
#          [ 38,  72,  65],
#          [ 39,  73,  66],
#          [ 39,  73,  66]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_7_4_png.rf.eb099bcea99cf692889ab77d9f679b5a.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.9803710005799076, 'inference': 151.22720200088224, 'postprocess': 0.7326359991566278},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 34,  35,  39],
#          [ 29,  30,  34],
#          [ 31,  33,  34],
#          ...,
#          [ 59,  77,  94],
#          [ 53,  72,  87],
#          [ 62,  81,  96]],
#
#         [[ 33,  34,  38],
#          [ 29,  30,  34],
#          [ 30,  32,  33],
#          ...,
#          [ 66,  82,  98],
#          [ 65,  81,  97],
#          [ 78,  94, 110]],
#
#         [[ 32,  34,  35],
#          [ 29,  31,  32],
#          [ 29,  31,  32],
#          ...,
#          [ 64,  79,  95],
#          [ 67,  82,  98],
#          [ 70,  86,  99]],
#
#         ...,
#
#         [[ 45,  40,  41],
#          [ 40,  38,  38],
#          [ 38,  43,  41],
#          ...,
#          [ 23,  31,  31],
#          [ 14,  21,  24],
#          [ 37,  44,  47]],
#
#         [[ 45,  40,  41],
#          [ 39,  37,  37],
#          [ 38,  43,  41],
#          ...,
#          [ 17,  25,  25],
#          [ 21,  28,  31],
#          [ 21,  28,  31]],
#
#         [[ 45,  40,  41],
#          [ 39,  37,  37],
#          [ 37,  42,  40],
#          ...,
#          [  4,  12,  12],
#          [ 33,  40,  43],
#          [ 16,  23,  26]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/744b27_9_9_png.rf.66884f75e67df321142d2600f1c7a3f1.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.0202769996540155, 'inference': 151.84369400049036, 'postprocess': 0.9178109994536499},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[  0,  43,  46],
#          [  0,  29,  32],
#          [ 10,  45,  49],
#          ...,
#          [ 30,  71,  74],
#          [ 33,  73,  78],
#          [ 24,  66,  71]],
#
#         [[ 40,  83,  86],
#          [ 20,  58,  62],
#          [ 37,  72,  76],
#          ...,
#          [ 27,  63,  69],
#          [ 34,  71,  79],
#          [ 32,  71,  79]],
#
#         [[ 71, 109, 111],
#          [ 37,  72,  75],
#          [ 55,  86,  89],
#          ...,
#          [ 38,  69,  78],
#          [ 43,  75,  86],
#          [ 38,  73,  83]],
#
#         ...,
#
#         [[105, 233, 232],
#          [105, 233, 232],
#          [105, 233, 232],
#          ...,
#          [ 17, 114, 124],
#          [ 12, 109, 119],
#          [ 20, 117, 127]],
#
#         [[102, 232, 231],
#          [102, 232, 231],
#          [103, 233, 232],
#          ...,
#          [ 20, 117, 127],
#          [ 29, 124, 134],
#          [ 32, 127, 137]],
#
#         [[102, 232, 231],
#          [102, 232, 231],
#          [102, 232, 231],
#          ...,
#          [ 55, 152, 162],
#          [ 75, 170, 180],
#          [ 72, 167, 177]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_3_10_png.rf.00e76ea90f2abc32e09334c3194c7c49.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.05323899940413, 'inference': 152.40916500079038, 'postprocess': 0.8887100011634175},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 21,  25,  26],
#          [ 22,  26,  27],
#          [ 23,  27,  28],
#          ...,
#          [ 11,  24,  22],
#          [ 11,  24,  22],
#          [ 16,  29,  27]],
#
#         [[ 23,  27,  28],
#          [ 23,  27,  28],
#          [ 22,  26,  27],
#          ...,
#          [ 15,  26,  24],
#          [ 17,  28,  26],
#          [ 24,  35,  33]],
#
#         [[ 24,  28,  29],
#          [ 23,  27,  28],
#          [ 21,  25,  26],
#          ...,
#          [ 22,  31,  28],
#          [ 25,  33,  32],
#          [ 32,  40,  39]],
#
#         ...,
#
#         [[ 87, 204, 195],
#          [ 87, 204, 195],
#          [ 87, 203, 196],
#          ...,
#          [ 25,  57,  56],
#          [ 37,  69,  68],
#          [ 44,  78,  77]],
#
#         [[ 86, 203, 194],
#          [ 86, 203, 194],
#          [ 87, 204, 195],
#          ...,
#          [ 39,  75,  75],
#          [ 33,  69,  69],
#          [ 28,  66,  66]],
#
#         [[ 85, 202, 193],
#          [ 86, 203, 194],
#          [ 87, 204, 195],
#          ...,
#          [ 30,  68,  68],
#          [ 31,  69,  69],
#          [ 31,  71,  70]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_3_3_png.rf.f62ed4e82697a2930b4d9bdd6ece0f9b.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.9019309988361783, 'inference': 153.16751300088072, 'postprocess': 0.7606870003655786},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[39, 58, 55],
#          [43, 64, 61],
#          [50, 74, 72],
#          ...,
#          [12, 25, 23],
#          [14, 27, 25],
#          [18, 31, 29]],
#
#         [[34, 53, 50],
#          [38, 59, 56],
#          [45, 69, 67],
#          ...,
#          [19, 32, 30],
#          [20, 33, 31],
#          [23, 36, 34]],
#
#         [[18, 37, 34],
#          [25, 46, 43],
#          [34, 56, 54],
#          ...,
#          [27, 40, 38],
#          [27, 40, 38],
#          [27, 40, 38]],
#
#         ...,
#
#         [[51, 96, 79],
#          [51, 96, 79],
#          [52, 96, 79],
#          ...,
#          [ 4, 26, 21],
#          [12, 13,  9],
#          [37, 28, 24]],
#
#         [[50, 98, 80],
#          [50, 98, 80],
#          [52, 97, 80],
#          ...,
#          [ 0, 18,  7],
#          [18, 23, 14],
#          [35, 26, 17]],
#
#         [[51, 99, 81],
#          [51, 99, 81],
#          [53, 98, 81],
#          ...,
#          [ 0, 21,  6],
#          [32, 38, 27],
#          [27, 17,  7]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/798b45_7_8_png.rf.30060820d1e9b058ac2c519039d057aa.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.86350400003721, 'inference': 153.0055449984502, 'postprocess': 0.9009320001496235},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[  6,  12,  23],
#          [  6,  12,  23],
#          [  6,  12,  23],
#          ...,
#          [ 31,  42,  56],
#          [ 31,  43,  55],
#          [ 29,  41,  53]],
#
#         [[  8,  14,  25],
#          [  8,  14,  25],
#          [  8,  14,  25],
#          ...,
#          [ 31,  41,  58],
#          [ 34,  44,  61],
#          [ 35,  46,  60]],
#
#         [[ 12,  18,  31],
#          [ 12,  18,  31],
#          [ 12,  18,  31],
#          ...,
#          [ 36,  45,  65],
#          [ 37,  46,  66],
#          [ 38,  47,  67]],
#
#         ...,
#
#         [[ 87,  90, 104],
#          [ 98, 101, 115],
#          [ 81,  83, 101],
#          ...,
#          [233, 233, 255],
#          [215, 213, 235],
#          [133, 131, 150]],
#
#         [[ 95,  97, 108],
#          [ 98, 100, 111],
#          [ 78,  78,  94],
#          ...,
#          [232, 231, 255],
#          [244, 242, 255],
#          [164, 165, 179]],
#
#         [[ 91,  93, 103],
#          [ 89,  91, 102],
#          [ 68,  69,  83],
#          ...,
#          [232, 229, 255],
#          [234, 235, 255],
#          [201, 203, 214]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/a9f16c_2_10_png.rf.7a5ffdc0b8955577fe953b92a257078b.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 3.948477000449202, 'inference': 152.8362709996145, 'postprocess': 0.9672309988673078},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 25,  33,  50],
#          [ 25,  33,  50],
#          [ 25,  33,  50],
#          ...,
#          [ 51,  96,  93],
#          [ 52,  91,  93],
#          [ 50,  89,  91]],
#
#         [[ 27,  35,  52],
#          [ 27,  36,  50],
#          [ 27,  35,  52],
#          ...,
#          [ 69, 115, 109],
#          [ 70, 110, 108],
#          [ 68, 108, 106]],
#
#         [[ 30,  39,  53],
#          [ 30,  39,  52],
#          [ 30,  39,  53],
#          ...,
#          [ 78, 126, 114],
#          [ 79, 122, 111],
#          [ 77, 120, 111]],
#
#         ...,
#
#         [[103, 117, 123],
#          [105, 119, 125],
#          [110, 122, 128],
#          ...,
#          [146, 159, 167],
#          [148, 160, 170],
#          [149, 161, 171]],
#
#         [[107, 121, 127],
#          [109, 123, 129],
#          [111, 125, 131],
#          ...,
#          [136, 151, 160],
#          [137, 152, 161],
#          [137, 152, 161]],
#
#         [[111, 125, 131],
#          [113, 127, 133],
#          [115, 129, 135],
#          ...,
#          [127, 142, 151],
#          [124, 139, 148],
#          [123, 138, 147]]], dtype=uint8)
#  orig_shape: (576, 576)
#  path: '/home/gomaa/Ai/projects/Football-Match-Analysis/data/football-players-detection-dataset/test/images/a9f16c_2_9_png.rf.3d70706303f110aedc833f5c8912b233.jpg'
#  probs: None
#  save_dir: '/home/gomaa/Ai/projects/Football-Match-Analysis/runs/predict2'
#  speed: {'preprocess': 4.102367000086815, 'inference': 153.2433199990919, 'postprocess': 0.6826909993833397}]

# %% [markdown]
# # DATASET ANALYSIS

# %%
import os
import yaml
import cv2
import numpy as np
from pathlib import Path
from collections import defaultdict, Counter
import random

def analyze_yolo_dataset(dataset_path, show_prints=True):
    """
    Analyze a YOLO format dataset and provide comprehensive insights.
    
    Args:
        dataset_path (str): Path to the dataset root directory containing data.yaml
        show_prints (bool): Whether to print statistics to console
    
    Returns:
        dict: Dictionary containing all computed statistics
    """
    
    dataset_path = Path(dataset_path)
    stats = {}
    
    # Load data.yaml
    yaml_path = dataset_path / 'data.yaml'
    if not yaml_path.exists():
        raise FileNotFoundError(f"data.yaml not found at {yaml_path}")
    
    with open(yaml_path, 'r') as f:
        data_config = yaml.safe_load(f)
    
    # Extract class information
    class_names = data_config.get('names', [])
    num_classes = data_config.get('nc', len(class_names))
    stats['classes'] = class_names
    stats['num_classes'] = num_classes
    
    if show_prints:
        print("=" * 60)
        print("YOLO DATASET ANALYSIS")
        print("=" * 60)
        print(f"\nClasses ({num_classes}):")
        for idx, name in enumerate(class_names):
            print(f"  {idx}: {name}")
    
    # Analyze each split
    splits = ['train', 'val', 'test']
    split_stats = {}
    all_class_counts = Counter()
    all_image_sizes = []
    
    for split in splits:
        if split not in data_config:
            continue
            
        split_path_str = data_config[split]
        
        # Handle both absolute and relative paths
        if os.path.isabs(split_path_str):
            split_path = Path(split_path_str)
        else:
            split_path = dataset_path / split_path_str
        
        # Determine images and labels paths - try multiple common structures
        images_path = None
        labels_path = None
        
        # Structure 1: split_path directly points to images folder
        if split_path.exists() and split_path.name == 'images':
            images_path = split_path
            labels_path = split_path.parent / 'labels'
        # Structure 2: split_path contains 'images' in the path
        elif 'images' in str(split_path):
            images_path = split_path
            labels_path = Path(str(split_path).replace('images', 'labels'))
        # Structure 3: split_path/images and split_path/labels
        elif (split_path / 'images').exists():
            images_path = split_path / 'images'
            labels_path = split_path / 'labels'
        # Structure 4: dataset_path/images/split and dataset_path/labels/split
        elif (dataset_path / 'images' / split).exists():
            images_path = dataset_path / 'images' / split
            labels_path = dataset_path / 'labels' / split
        else:
            # Default assumption
            images_path = split_path
            labels_path = split_path.parent / 'labels' if split_path.parent.name == 'images' else split_path / 'labels'
        
        if not images_path.exists():
            continue
        
        # Get image files
        image_files = list(images_path.glob('*.jpg')) + list(images_path.glob('*.png')) + \
                     list(images_path.glob('*.jpeg')) + list(images_path.glob('*.JPG')) + \
                     list(images_path.glob('*.PNG')) + list(images_path.glob('*.JPEG'))
        
        num_images = len(image_files)
        split_stats[split] = {
            'num_images': num_images,
            'image_sizes': [],
            'class_counts': Counter(),
            'images_path': images_path,
            'labels_path': labels_path
        }
        
        # Analyze images and labels
        for img_file in image_files:
            # Get image size
            img = cv2.imread(str(img_file))
            if img is not None:
                h, w = img.shape[:2]
                split_stats[split]['image_sizes'].append((w, h))
                all_image_sizes.append((w, h))
            
            # Count classes in labels - try different label file locations
            label_file = labels_path / f"{img_file.stem}.txt"
            
            # If label file doesn't exist in expected location, try same directory
            if not label_file.exists():
                label_file = img_file.parent.parent / 'labels' / img_file.parent.name / f"{img_file.stem}.txt"
            
            if not label_file.exists():
                # Try parallel labels directory
                label_file = img_file.parent.parent / 'labels' / f"{img_file.stem}.txt"
            
            if label_file.exists():
                try:
                    with open(label_file, 'r') as f:
                        for line in f:
                            line = line.strip()
                            if line:  # Skip empty lines
                                parts = line.split()
                                if parts:
                                    try:
                                        class_id = int(parts[0])
                                        if 0 <= class_id < num_classes:
                                            split_stats[split]['class_counts'][class_id] += 1
                                            all_class_counts[class_id] += 1
                                    except (ValueError, IndexError):
                                        continue
                except Exception as e:
                    if show_prints:
                        print(f"Warning: Could not read label file {label_file}: {e}")
    
    stats['splits'] = split_stats
    stats['total_images'] = sum(s['num_images'] for s in split_stats.values())
    stats['all_class_counts'] = all_class_counts
    
    # Print statistics
    if show_prints:
        print(f"\n{'=' * 60}")
        print("DATASET DISTRIBUTION")
        print("=" * 60)
        print(f"\nTotal Images: {stats['total_images']}")
        
        for split in splits:
            if split in split_stats:
                print(f"  {split.capitalize()}: {split_stats[split]['num_images']} images")
        
        print(f"\n{'=' * 60}")
        print("IMAGE SIZES")
        print("=" * 60)
        
        for split in splits:
            if split in split_stats and split_stats[split]['image_sizes']:
                sizes = split_stats[split]['image_sizes']
                unique_sizes = set(sizes)
                print(f"\n{split.capitalize()}:")
                print(f"  Unique sizes: {len(unique_sizes)}")
                if len(unique_sizes) <= 5:
                    for size in unique_sizes:
                        count = sizes.count(size)
                        print(f"    {size[0]}x{size[1]}: {count} images")
                else:
                    size_counter = Counter(sizes)
                    print(f"  Most common sizes:")
                    for size, count in size_counter.most_common(3):
                        print(f"    {size[0]}x{size[1]}: {count} images")
        
        print(f"\n{'=' * 60}")
        print("CLASS DISTRIBUTION")
        print("=" * 60)
        print(f"\nTotal Instances per Class:")
        
        for class_id in range(num_classes):
            class_name = class_names[class_id] if class_id < len(class_names) else f"Class_{class_id}"
            total_count = all_class_counts.get(class_id, 0)
            print(f"  {class_name}: {total_count}")
            
            split_details = []
            for split in splits:
                if split in split_stats:
                    count = split_stats[split]['class_counts'].get(class_id, 0)
                    if count > 0:
                        split_details.append(f"{split}={count}")
            
            if split_details:
                print(f"    ({', '.join(split_details)})")
    
    
    return stats

# %%
stats = analyze_yolo_dataset(
    dataset_path=DATASET_PATH,
    show_prints=True
)
# Out:
# ============================================================
# YOLO DATASET ANALYSIS
# ============================================================
#
# Classes (4):
#   0: ball
#   1: goalkeeper
#   2: player
#   3: referee
#
# ============================================================
# DATASET DISTRIBUTION
# ============================================================
#
# Total Images: 372
#   Train: 298 images
#   Val: 49 images
#   Test: 25 images
#
# ============================================================
# IMAGE SIZES
# ============================================================
#
# Train:
#   Unique sizes: 1
#     576x576: 298 images
#
# Val:
#   Unique sizes: 1
#     576x576: 49 images
#
# Test:
#   Unique sizes: 1
#     576x576: 25 images
#
# ============================================================
# CLASS DISTRIBUTION
# ============================================================
#
# Total Instances per Class:
#   ball: 327
#     (train=258, val=45, test=24)
#   goalkeeper: 288
#     (train=230, val=39, test=19)
#   player: 7427
#     (train=5955, val=973, test=499)
#   referee: 863
#     (train=690, val=117, test=56)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from pathlib import Path
import random
import yaml


def plot_yolo_samples(dataset_path, stats, num_samples=6, splits=['train', 'val', 'test']):
    """
    Plot random sample images with labels from YOLO dataset splits.
    
    Args:
        dataset_path (str): Path to the dataset root directory containing data.yaml
        stats (dict): Statistics dictionary returned from analyze_yolo_dataset()
        num_samples (int): Number of random images to plot per split
        splits (list): List of splits to plot (e.g., ['train', 'val', 'test'])
    """
    
    dataset_path = Path(dataset_path)
    
    # Load data.yaml to get class names and paths
    yaml_path = dataset_path / 'data.yaml'
    if not yaml_path.exists():
        raise FileNotFoundError(f"data.yaml not found at {yaml_path}")
    
    with open(yaml_path, 'r') as f:
        data_config = yaml.safe_load(f)
    
    class_names = stats.get('classes', [])
    
    # Plot samples for each split
    for split in splits:
        if split not in stats['splits'] or stats['splits'][split]['num_images'] == 0:
            print(f"Skipping {split} - no images found")
            continue
        
        images_path = stats['splits'][split]['images_path']
        labels_path = stats['splits'][split]['labels_path']
        
        # Get all image files
        image_files = list(images_path.glob('*.jpg')) + list(images_path.glob('*.png')) + \
                     list(images_path.glob('*.jpeg')) + list(images_path.glob('*.JPG')) + \
                     list(images_path.glob('*.PNG')) + list(images_path.glob('*.JPEG'))
        
        if len(image_files) == 0:
            print(f"No image files found in {images_path}")
            continue
        
        # Select random samples
        sample_size = min(num_samples, len(image_files))
        sampled_images = random.sample(image_files, sample_size)
        
        # Create subplot grid
        cols = 3
        rows = (sample_size + cols - 1) // cols
        fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows))
        fig.suptitle(f'{split.capitalize()} Dataset - Random Samples with Labels', 
                    fontsize=16, fontweight='bold')
        
        # Handle single image case
        if sample_size == 1:
            axes = np.array([axes])
        axes = axes.flatten() if sample_size > 1 else axes
        
        # Plot each sampled image
        for idx, img_file in enumerate(sampled_images):
            img = cv2.imread(str(img_file))
            if img is None:
                print(f"Warning: Could not read image {img_file}")
                continue
            
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            h, w = img.shape[:2]
            
            ax = axes[idx]
            ax.imshow(img)
            
            # Find corresponding label file
            label_file = labels_path / f"{img_file.stem}.txt"
            
            # Try alternative label locations if not found
            if not label_file.exists():
                label_file = img_file.parent.parent / 'labels' / img_file.parent.name / f"{img_file.stem}.txt"
            
            if not label_file.exists():
                label_file = img_file.parent.parent / 'labels' / f"{img_file.stem}.txt"
            
            # Draw bounding boxes and labels
            num_objects = 0
            if label_file.exists():
                try:
                    with open(label_file, 'r') as f:
                        for line in f:
                            line = line.strip()
                            if not line:
                                continue
                            
                            parts = line.split()
                            if len(parts) >= 5:
                                try:
                                    class_id = int(parts[0])
                                    x_center, y_center, width, height = map(float, parts[1:5])
                                    
                                    # Convert YOLO format (normalized) to pixel coordinates
                                    x_center *= w
                                    y_center *= h
                                    width *= w
                                    height *= h
                                    
                                    x1 = x_center - width / 2
                                    y1 = y_center - height / 2
                                    
                                    # Draw bounding box
                                    rect = patches.Rectangle((x1, y1), width, height, 
                                                            linewidth=2, edgecolor='red', 
                                                            facecolor='none')
                                    ax.add_patch(rect)
                                    
                                    # Add class label with background
                                    class_name = class_names[class_id] if class_id < len(class_names) else f"Class_{class_id}"
                                    ax.text(x1, y1 - 5, class_name, color='white', 
                                           fontsize=9, fontweight='bold',
                                           bbox=dict(boxstyle='round,pad=0.3', 
                                                   facecolor='red', alpha=0.8))
                                    
                                    num_objects += 1
                                except (ValueError, IndexError) as e:
                                    print(f"Warning: Malformed label in {label_file}: {line}")
                                    continue
                except Exception as e:
                    print(f"Warning: Could not read label file {label_file}: {e}")
            
            ax.axis('off')
            ax.set_title(f"{img_file.name}\n({w}x{h}, {num_objects} objects)", 
                        fontsize=9)
        
        # Hide extra subplots
        for idx in range(sample_size, len(axes)):
            axes[idx].axis('off')
        
        plt.tight_layout()
        plt.show()
    
    print(f"\nPlotted samples from {len([s for s in splits if s in stats['splits']])} split(s)")

# %%
plot_yolo_samples(DATASET_PATH, stats, num_samples=6, splits=['train', 'val', 'test'])
# Out:
# Plotted samples from 3 split(s)
